# %% [markdown]
# # Expresiones Regulares - NLP

# %% [markdown]
# ## (1) Regex en Atención al Cliente - Chatbot

# %% [markdown]
# ![imagen.png](attachment:d80b4945-79ff-4592-b82e-3f2abcc4b924.png)

# %% [markdown]
# ## Recuperar el número de orden del cliente

# %% [markdown]
# El reclamo puede comenzar de esta forma:

# %% [markdown]
# ![imagen.png](attachment:8c57c13d-a20e-42ad-8b99-3e466f77c672.png)

# %% [markdown]
# Seguido, a que a su vez el chatbot le pida su número de telefono y el mail asociado al mismo:

# %% [markdown]
# ![imagen.png](attachment:e1ecd4d6-a9db-4ad9-a8ca-0c4d981f09d0.png)

# %% [markdown]
# Que podría incluir todos estos formatos:

# %% [markdown]
# ![imagen.png](attachment:ca3b1a4d-d961-46b5-8aa0-c882d1ed67b4.png)

# %%
import re

chat1 = 'codebasics: you ask lot of questions 😠  1235678912, abc@xyz.com'
chat2 = 'codebasics: here it is: (123)-567-8912, abc_x98@xyz.com'
chat3 = 'codebasics: yes, phone: 1235678912 email: abc@xyz.edu.ar'

pattern = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'

busqueda = re.findall (pattern, chat3)
busqueda
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\2458935448.py:7: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'
# ['1235678912']

# %%
pattern_mail = '[a-z0-9A-Z_]*@[a-z0-9A-Z]*.[a-zA-Z]*.[a-z]*'

busqueda_mail = re.findall(pattern_mail, chat3)
busqueda_mail
# Out:
# ['abc@xyz.edu.ar']

# %%
import re

chat1='codebasics: Hello, I am having an issue with my order # 412889912'

pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat1)
matches
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\2711217440.py:5: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'order[^\d]*(\d*)'
# ['412889912']

# %%
chat2='codebasics: I have a problem with my order number 412889912'
pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat2)
matches
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\2125409380.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'order[^\d]*(\d*)'
# ['412889912']

# %%
chat3='codebasics: My order 412889912 is having an issue, I was charged 300$ when online it says 280$'
pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat3)
matches
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\3316829242.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'order[^\d]*(\d*)'
# ['412889912']

# %%
def get_pattern_match(pattern, text):
    matches = re.findall(pattern, text)
    if matches:
        return matches[0]

# %%
get_pattern_match('order[^\d]*(\d*)', chat1)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\1612910112.py:1: SyntaxWarning: invalid escape sequence '\d'
#   get_pattern_match('order[^\d]*(\d*)', chat1)
# '412889912'

# %% [markdown]
# <h3>Retrieve email id and phone</h3>

# %%
chat1 = 'codebasics: you ask lot of questions 😠  1235678912, abc@xyz.com'
chat2 = 'codebasics: here it is: (123)-567-8912, abc@xyz.com'
chat3 = 'codebasics: yes, phone: 1235678912 email: abc@xyz.com'

# %% [markdown]
# **-----Email id-----**

# %%
get_pattern_match('[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*',chat1)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\2536982304.py:1: SyntaxWarning: invalid escape sequence '\.'
#   get_pattern_match('[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*',chat1)
# 'abc@xyz.com'

# %%
get_pattern_match('[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*',chat2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\3553579369.py:1: SyntaxWarning: invalid escape sequence '\.'
#   get_pattern_match('[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*',chat2)
# 'abc@xyz.com'

# %%
get_pattern_match('[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*',chat3)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\2716949903.py:1: SyntaxWarning: invalid escape sequence '\.'
#   get_pattern_match('[a-zA-Z0-9_]*@[a-z]*\.[a-zA-Z0-9]*',chat3)
# 'abc@xyz.com'

# %% [markdown]
# **-----Phone number-----**

# %%
get_pattern_match('(\d{10})|(\(\d{3}\)-\d{3}-\d{4})',chat1)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\632513232.py:1: SyntaxWarning: invalid escape sequence '\d'
#   get_pattern_match('(\d{10})|(\(\d{3}\)-\d{3}-\d{4})',chat1)
# ('1235678912', '')

# %%
get_pattern_match('(\d{10})|(\(\d{3}\)-\d{3}-\d{4})', chat2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\829666669.py:1: SyntaxWarning: invalid escape sequence '\d'
#   get_pattern_match('(\d{10})|(\(\d{3}\)-\d{3}-\d{4})', chat2)
# ('', '(123)-567-8912')

# %%
get_pattern_match('(\d{10})|(\(\d{3}\)-\d{3}-\d{4})', chat3)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\1592073293.py:1: SyntaxWarning: invalid escape sequence '\d'
#   get_pattern_match('(\d{10})|(\(\d{3}\)-\d{3}-\d{4})', chat3)
# ('1235678912', '')

# %% [markdown]
# ## (2) Regex para Extracción de Información

# %%
text='''
Born	Elon Reeve Musk
June 28, 1971 (age 50)
Pretoria, Transvaal, South Africa
Citizenship	
South Africa (1971–present)
Canada (1971–present)
United States (2002–present)
Education	University of Pennsylvania (BS, BA)
Title	
Founder, CEO and Chief Engineer of SpaceX
CEO and product architect of Tesla, Inc.
Founder of The Boring Company and X.com (now part of PayPal)
Co-founder of Neuralink, OpenAI, and Zip2
Spouse(s)	
Justine Wilson
​
​(m. 2000; div. 2008)​
Talulah Riley
​
​(m. 2010; div. 2012)​
​
​(m. 2013; div. 2016)
'''

# %%
get_pattern_match(r'age (\d+)', text)
# Out:
# '50'

# %%
get_pattern_match(r'Born(.*)\n', text).strip()
# Out:
# 'Elon Reeve Musk'

# %%
get_pattern_match(r'Born.*\n(.*)\(age', text).strip()
# Out:
# 'June 28, 1971'

# %%
get_pattern_match(r'\(age.*\n(.*)', text)
# Out:
# 'Pretoria, Transvaal, South Africa'

# %%
def extract_personal_information(text):
    age = get_pattern_match('age (\d+)', text)
    full_name = get_pattern_match('Born(.*)\n', text)
    birth_date = get_pattern_match('Born.*\n(.*)\(age', text)
    birth_place = get_pattern_match('\(age.*\n(.*)', text)
    return {
        'age': int(age),
        'name': full_name.strip(),
        'birth_date': birth_date.strip(),
        'birth_place': birth_place.strip()
    }
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\('
# <>:5: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\('
# <>:5: SyntaxWarning: invalid escape sequence '\('
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\3783779278.py:2: SyntaxWarning: invalid escape sequence '\d'
#   age = get_pattern_match('age (\d+)', text)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\3783779278.py:4: SyntaxWarning: invalid escape sequence '\('
#   birth_date = get_pattern_match('Born.*\n(.*)\(age', text)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9940\3783779278.py:5: SyntaxWarning: invalid escape sequence '\('
#   birth_place = get_pattern_match('\(age.*\n(.*)', text)

# %%
extract_personal_information(text)
# Out:
# {'age': 50,
#  'name': 'Elon Reeve Musk',
#  'birth_date': 'June 28, 1971',
#  'birth_place': 'Pretoria, Transvaal, South Africa'}

# %%
text = '''
Born	Mukesh Dhirubhai Ambani
19 April 1957 (age 64)
Aden, Colony of Aden
(present-day Yemen)[1][2]
Nationality	Indian
Alma mater	
St. Xavier's College, Mumbai
Institute of Chemical Technology (B.E.)
Stanford University (drop-out)
Occupation	Chairman and MD, Reliance Industries
Spouse(s)	Nita Ambani ​(m. 1985)​[3]
Children	3
Parent(s)	
Dhirubhai Ambani (father)
Kokilaben Ambani (mother)
Relatives	Anil Ambani (brother)
Tina Ambani (sister-in-law)
'''

# %%
extract_personal_information(text)
# Out:
# {'age': 64,
#  'name': 'Mukesh Dhirubhai Ambani',
#  'birth_date': '19 April 1957',
#  'birth_place': 'Aden, Colony of Aden'}
